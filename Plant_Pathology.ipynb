# %% [markdown]
# <a href="https://colab.research.google.com/github/quainhan1110/Plant-Pathology-Classification/blob/main/Plant_Pathology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import PIL
import tensorflow as tf
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.metrics import classification_report 

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# !git clone https://github.com/quainhan1110/Plant_Pathology.git
# Out:
# Cloning into 'Plant_Pathology'...
# remote: Enumerating objects: 3675, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 3675 (delta 11), reused 1 (delta 0), pack-reused 3647
# Receiving objects: 100% (3675/3675), 779.65 MiB | 16.97 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# Checking out files: 100% (3645/3645), done.

# %%
df = pd.read_csv("/content/Plant_Pathology/plant-pathology-2020-fgvc7-data/train.csv")
df.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %%
import shutil
from shutil import copyfile

# delete temp dir
if os.path.exists('/content/Plant_Pathology/tmp/'):
    shutil.rmtree('/content/Plant_Pathology/tmp/')

os.mkdir('/content/Plant_Pathology/tmp/')

# create new directory for each category of foliar diseases
os.mkdir('/content/Plant_Pathology/tmp/healthy')
os.mkdir('/content/Plant_Pathology/tmp/multiple_diseases')
os.mkdir('/content/Plant_Pathology/tmp/rust')
os.mkdir('/content/Plant_Pathology/tmp/scab')

# %%
SOURCE = '/content/Plant_Pathology/plant-pathology-2020-fgvc7-data/images/'

TMP_DIR = '/content/Plant_Pathology/tmp/'

for i in range(len(df)):
  label = df.columns[np.argmax(df.iloc[i][1:])+1]
  filepath = os.path.join(SOURCE,df.iloc[i].image_id + ".jpg")
  dest = os.path.join(TMP_DIR,label,df.iloc[i].image_id + ".jpg")
  copyfile(filepath, dest)

sizes = []
labels = []
for subdir in os.listdir(TMP_DIR):
    print(subdir, len(os.listdir(os.path.join(TMP_DIR, subdir))))
    sizes.append(len(os.listdir(os.path.join(TMP_DIR, subdir))))
    labels.append(subdir)
# Out:
# rust 622
# healthy 516
# multiple_diseases 91
# scab 592

# %%
plt.figure(figsize=(7, 7))
plt.bar(labels, sizes)
plt.show()

# %%
healthy_dir = os.path.join(TMP_DIR, 'healthy')
mdiseases_dir = os.path.join(TMP_DIR, 'multiple_diseases')
scab_dir = os.path.join(TMP_DIR, 'scab')
rust_dir = os.path.join(TMP_DIR, 'rust')

healthy_files = os.listdir(healthy_dir)
mdiseases_files = os.listdir(mdiseases_dir)
scab_files = os.listdir(scab_dir)
rust_files = os.listdir(rust_dir)

# %%
pic_index = 2

next_healthy = [os.path.join(healthy_dir, fname) for fname in healthy_files[pic_index-2:pic_index]]
next_mdiseases = [os.path.join(mdiseases_dir, fname) for fname in mdiseases_files[pic_index-2:pic_index]]
next_scab = [os.path.join(scab_dir, fname) for fname in scab_files[pic_index-2:pic_index]]
next_rust = [os.path.join(rust_dir, fname) for fname in rust_files[pic_index-2:pic_index]]


nrows = 4
ncols = 4

fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

for i, img_path in enumerate(next_healthy+next_mdiseases+next_scab+next_rust):
    sp = plt.subplot(nrows, ncols, i + 1)
    sp.axis('Off')
    img = mpimg.imread(img_path)
    plt.title(img_path.split('/')[-2])
    plt.imshow(img)
    
plt.show()

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  TMP_DIR,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  label_mode='categorical')
# Out:
# Found 1821 files belonging to 4 classes.
# Using 1457 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
    TMP_DIR,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    label_mode='categorical'
)
# Out:
# Found 1821 files belonging to 4 classes.
# Using 364 files for validation.

# %%
class_names = train_ds.class_names
num_classes = len(class_names)
print(class_names)
# Out:
# ['healthy', 'multiple_diseases', 'rust', 'scab']

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32, 4)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes,activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 11, 11, 128)       0
#
#  flatten (Flatten)           (None, 15488)             0
#
#  dense (Dense)               (None, 128)               1982592
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 2,080,548
# Trainable params: 2,080,548
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Use Early Stopping to halt the training of neural network at the right time, and CheckPointing to save the best model during training for later use.

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10,
                                                  monitor="val_loss",
                                                  verbose=2,
                                                  mode="auto")
checkpoint = tf.keras.callbacks.ModelCheckpoint("best.h5", 
                                                monitor="val_loss",
                                                mode="auto",
                                                verbose=2,
                                                save_best_only=True)
model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
epochs = 100

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping,checkpoint]
)
# Out:
# Epoch 1/100
# 45/46 [============================>.] - ETA: 0s - loss: 1.2821 - accuracy: 0.3256
# Epoch 1: val_loss improved from inf to 1.28097, saving model to best.h5
# 46/46 [==============================] - 18s 107ms/step - loss: 1.2809 - accuracy: 0.3288 - val_loss: 1.2810 - val_accuracy: 0.3269
# Epoch 2/100
# 45/46 [============================>.] - ETA: 0s - loss: 1.2338 - accuracy: 0.3474
# Epoch 2: val_loss did not improve from 1.28097
# 46/46 [==============================] - 1s 30ms/step - loss: 1.2326 - accuracy: 0.3473 - val_loss: 1.2850 - val_accuracy: 0.3269
# Epoch 3/100
# 44/46 [===========================>..] - ETA: 0s - loss: 1.2550 - accuracy: 0.3209
# Epoch 3: val_loss improved from 1.28097 to 1.26489, saving model to best.h5
# 46/46 [==============================] - 1s 29ms/step - loss: 1.2521 - accuracy: 0.3226 - val_loss: 1.2649 - val_accuracy: 0.3379
# Epoch 4/100
# 45/46 [============================>.] - ETA: 0s - loss: 1.2361 - accuracy: 0.3551
# Epoch 4: val_loss improved from 1.26489 to 1.26181, saving model to best.h5
# 46/46 [==============================] - 1s 29ms/step - loss: 1.2348 - accuracy: 0.3576 - val_loss: 1.2618 - val_accuracy: 0.3462
# Epoch 5/100
# 45/46 [============================>.] - ETA: 0s - loss: 1.2279 - accuracy: 0.3607
# Epoch 5: val_loss did not improve from 1.26181
# 46/46 [==============================] - 1s 28ms/step - loss: 1.2277 - accuracy: 0.3617 - val_loss: 1.2748 - val_accuracy: 0.3214
# Epoch 6/100
# 46/46 [==============================] - ETA: 0s - loss: 1.2326 - accuracy: 0.3644
# Epoch 6: val_loss improved from 1.26181 to 1.26010, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 1.2326 - accuracy: 0.3644 - val_loss: 1.2601 - val_accuracy: 0.4176
# Epoch 7/100
# 46/46 [==============================] - ETA: 0s - loss: 1.2195 - accuracy: 0.3617
# Epoch 7: val_loss improved from 1.26010 to 1.25390, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 1.2195 - accuracy: 0.3617 - val_loss: 1.2539 - val_accuracy: 0.4093
# Epoch 8/100
# 46/46 [==============================] - ETA: 0s - loss: 1.1878 - accuracy: 0.4194
# Epoch 8: val_loss improved from 1.25390 to 1.21414, saving model to best.h5
# 46/46 [==============================] - 1s 29ms/step - loss: 1.1878 - accuracy: 0.4194 - val_loss: 1.2141 - val_accuracy: 0.4505
# Epoch 9/100
# 45/46 [============================>.] - ETA: 0s - loss: 1.1578 - accuracy: 0.4653
# Epoch 9: val_loss improved from 1.21414 to 1.21373, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 1.1643 - accuracy: 0.4626 - val_loss: 1.2137 - val_accuracy: 0.4396
# Epoch 10/100
# 45/46 [============================>.] - ETA: 0s - loss: 1.1560 - accuracy: 0.4744
# Epoch 10: val_loss improved from 1.21373 to 1.16230, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 1.1538 - accuracy: 0.4763 - val_loss: 1.1623 - val_accuracy: 0.4670
# Epoch 11/100
# 44/46 [===========================>..] - ETA: 0s - loss: 1.1226 - accuracy: 0.4794
# Epoch 11: val_loss did not improve from 1.16230
# 46/46 [==============================] - 1s 28ms/step - loss: 1.1259 - accuracy: 0.4804 - val_loss: 1.3159 - val_accuracy: 0.4066
# Epoch 12/100
# 44/46 [===========================>..] - ETA: 0s - loss: 1.1130 - accuracy: 0.5075
# Epoch 12: val_loss did not improve from 1.16230
# 46/46 [==============================] - 1s 28ms/step - loss: 1.1169 - accuracy: 0.5058 - val_loss: 1.1869 - val_accuracy: 0.4670
# Epoch 13/100
# 45/46 [============================>.] - ETA: 0s - loss: 1.1078 - accuracy: 0.5200
# Epoch 13: val_loss improved from 1.16230 to 1.14862, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 1.1104 - accuracy: 0.5189 - val_loss: 1.1486 - val_accuracy: 0.5000
# Epoch 14/100
# 45/46 [============================>.] - ETA: 0s - loss: 1.0459 - accuracy: 0.5635
# Epoch 14: val_loss did not improve from 1.14862
# 46/46 [==============================] - 1s 28ms/step - loss: 1.0435 - accuracy: 0.5662 - val_loss: 1.1651 - val_accuracy: 0.5000
# Epoch 15/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.9556 - accuracy: 0.6056
# Epoch 15: val_loss improved from 1.14862 to 0.94706, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.9502 - accuracy: 0.6088 - val_loss: 0.9471 - val_accuracy: 0.6511
# Epoch 16/100
# 46/46 [==============================] - ETA: 0s - loss: 0.7440 - accuracy: 0.7193
# Epoch 16: val_loss improved from 0.94706 to 0.81042, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.7440 - accuracy: 0.7193 - val_loss: 0.8104 - val_accuracy: 0.7060
# Epoch 17/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.6748 - accuracy: 0.7551
# Epoch 17: val_loss improved from 0.81042 to 0.70759, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.6797 - accuracy: 0.7515 - val_loss: 0.7076 - val_accuracy: 0.7198
# Epoch 18/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.6325 - accuracy: 0.7537
# Epoch 18: val_loss improved from 0.70759 to 0.68427, saving model to best.h5
# 46/46 [==============================] - 1s 31ms/step - loss: 0.6374 - accuracy: 0.7529 - val_loss: 0.6843 - val_accuracy: 0.7390
# Epoch 19/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.5832 - accuracy: 0.7753
# Epoch 19: val_loss improved from 0.68427 to 0.65213, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.5856 - accuracy: 0.7714 - val_loss: 0.6521 - val_accuracy: 0.7308
# Epoch 20/100
# 46/46 [==============================] - ETA: 0s - loss: 0.5464 - accuracy: 0.7865
# Epoch 20: val_loss improved from 0.65213 to 0.59865, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.5464 - accuracy: 0.7865 - val_loss: 0.5986 - val_accuracy: 0.7830
# Epoch 21/100
# 46/46 [==============================] - ETA: 0s - loss: 0.5633 - accuracy: 0.7872
# Epoch 21: val_loss did not improve from 0.59865
# 46/46 [==============================] - 1s 28ms/step - loss: 0.5633 - accuracy: 0.7872 - val_loss: 0.6126 - val_accuracy: 0.7582
# Epoch 22/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.4806 - accuracy: 0.8239
# Epoch 22: val_loss improved from 0.59865 to 0.55380, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.4840 - accuracy: 0.8216 - val_loss: 0.5538 - val_accuracy: 0.7940
# Epoch 23/100
# 46/46 [==============================] - ETA: 0s - loss: 0.4855 - accuracy: 0.8140
# Epoch 23: val_loss did not improve from 0.55380
# 46/46 [==============================] - 1s 28ms/step - loss: 0.4855 - accuracy: 0.8140 - val_loss: 0.6001 - val_accuracy: 0.7720
# Epoch 24/100
# 46/46 [==============================] - ETA: 0s - loss: 0.4491 - accuracy: 0.8325
# Epoch 24: val_loss did not improve from 0.55380
# 46/46 [==============================] - 1s 28ms/step - loss: 0.4491 - accuracy: 0.8325 - val_loss: 0.7446 - val_accuracy: 0.7363
# Epoch 25/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.4238 - accuracy: 0.8435
# Epoch 25: val_loss improved from 0.55380 to 0.45928, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.4224 - accuracy: 0.8463 - val_loss: 0.4593 - val_accuracy: 0.8352
# Epoch 26/100
# 46/46 [==============================] - ETA: 0s - loss: 0.4119 - accuracy: 0.8559
# Epoch 26: val_loss did not improve from 0.45928
# 46/46 [==============================] - 1s 28ms/step - loss: 0.4119 - accuracy: 0.8559 - val_loss: 0.4637 - val_accuracy: 0.8269
# Epoch 27/100
# 46/46 [==============================] - ETA: 0s - loss: 0.3776 - accuracy: 0.8614
# Epoch 27: val_loss did not improve from 0.45928
# 46/46 [==============================] - 1s 28ms/step - loss: 0.3776 - accuracy: 0.8614 - val_loss: 0.4815 - val_accuracy: 0.8352
# Epoch 28/100
# 46/46 [==============================] - ETA: 0s - loss: 0.3883 - accuracy: 0.8531
# Epoch 28: val_loss did not improve from 0.45928
# 46/46 [==============================] - 1s 28ms/step - loss: 0.3883 - accuracy: 0.8531 - val_loss: 0.4882 - val_accuracy: 0.8297
# Epoch 29/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.3482 - accuracy: 0.8842
# Epoch 29: val_loss did not improve from 0.45928
# 46/46 [==============================] - 1s 28ms/step - loss: 0.3474 - accuracy: 0.8847 - val_loss: 0.4726 - val_accuracy: 0.8462
# Epoch 30/100
# 46/46 [==============================] - ETA: 0s - loss: 0.3142 - accuracy: 0.8806
# Epoch 30: val_loss improved from 0.45928 to 0.44898, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.3142 - accuracy: 0.8806 - val_loss: 0.4490 - val_accuracy: 0.8462
# Epoch 31/100
# 46/46 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.8861
# Epoch 31: val_loss did not improve from 0.44898
# 46/46 [==============================] - 1s 28ms/step - loss: 0.3121 - accuracy: 0.8861 - val_loss: 0.5930 - val_accuracy: 0.7885
# Epoch 32/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.3261 - accuracy: 0.8856
# Epoch 32: val_loss improved from 0.44898 to 0.36579, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.3217 - accuracy: 0.8874 - val_loss: 0.3658 - val_accuracy: 0.8599
# Epoch 33/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2621 - accuracy: 0.8998
# Epoch 33: val_loss did not improve from 0.36579
# 46/46 [==============================] - 1s 28ms/step - loss: 0.2621 - accuracy: 0.8998 - val_loss: 0.3965 - val_accuracy: 0.8544
# Epoch 34/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.2646 - accuracy: 0.9095
# Epoch 34: val_loss did not improve from 0.36579
# 46/46 [==============================] - 1s 28ms/step - loss: 0.2657 - accuracy: 0.9094 - val_loss: 0.4145 - val_accuracy: 0.8571
# Epoch 35/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.2701 - accuracy: 0.9039
# Epoch 35: val_loss did not improve from 0.36579
# 46/46 [==============================] - 1s 28ms/step - loss: 0.2723 - accuracy: 0.9039 - val_loss: 0.3949 - val_accuracy: 0.8626
# Epoch 36/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.2347 - accuracy: 0.9158
# Epoch 36: val_loss improved from 0.36579 to 0.34471, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.2350 - accuracy: 0.9170 - val_loss: 0.3447 - val_accuracy: 0.8846
# Epoch 37/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.2352 - accuracy: 0.9123
# Epoch 37: val_loss improved from 0.34471 to 0.32663, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.2346 - accuracy: 0.9128 - val_loss: 0.3266 - val_accuracy: 0.8929
# Epoch 38/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2203 - accuracy: 0.9231
# Epoch 38: val_loss did not improve from 0.32663
# 46/46 [==============================] - 1s 29ms/step - loss: 0.2203 - accuracy: 0.9231 - val_loss: 0.3360 - val_accuracy: 0.8819
# Epoch 39/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2292 - accuracy: 0.9218
# Epoch 39: val_loss did not improve from 0.32663
# 46/46 [==============================] - 1s 29ms/step - loss: 0.2292 - accuracy: 0.9218 - val_loss: 0.3507 - val_accuracy: 0.8681
# Epoch 40/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.2239 - accuracy: 0.9200
# Epoch 40: val_loss did not improve from 0.32663
# 46/46 [==============================] - 1s 29ms/step - loss: 0.2268 - accuracy: 0.9190 - val_loss: 0.3462 - val_accuracy: 0.8846
# Epoch 41/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.2286 - accuracy: 0.9203
# Epoch 41: val_loss improved from 0.32663 to 0.29704, saving model to best.h5
# 46/46 [==============================] - 1s 30ms/step - loss: 0.2226 - accuracy: 0.9231 - val_loss: 0.2970 - val_accuracy: 0.8956
# Epoch 42/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1804 - accuracy: 0.9411
# Epoch 42: val_loss did not improve from 0.29704
# 46/46 [==============================] - 1s 28ms/step - loss: 0.1792 - accuracy: 0.9430 - val_loss: 0.4676 - val_accuracy: 0.8599
# Epoch 43/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9403
# Epoch 43: val_loss did not improve from 0.29704
# 46/46 [==============================] - 1s 29ms/step - loss: 0.1717 - accuracy: 0.9403 - val_loss: 0.3238 - val_accuracy: 0.8929
# Epoch 44/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1703 - accuracy: 0.9361
# Epoch 44: val_loss did not improve from 0.29704
# 46/46 [==============================] - 1s 28ms/step - loss: 0.1694 - accuracy: 0.9362 - val_loss: 0.3302 - val_accuracy: 0.8901
# Epoch 45/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9286
# Epoch 45: val_loss did not improve from 0.29704
# 46/46 [==============================] - 1s 29ms/step - loss: 0.1749 - accuracy: 0.9286 - val_loss: 0.3726 - val_accuracy: 0.8681
# Epoch 46/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1675 - accuracy: 0.9389
# Epoch 46: val_loss did not improve from 0.29704
# 46/46 [==============================] - 1s 28ms/step - loss: 0.1675 - accuracy: 0.9389 - val_loss: 0.3945 - val_accuracy: 0.8599
# Epoch 47/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1523 - accuracy: 0.9472
# Epoch 47: val_loss did not improve from 0.29704
# 46/46 [==============================] - 1s 28ms/step - loss: 0.1537 - accuracy: 0.9472 - val_loss: 0.3375 - val_accuracy: 0.8901
# Epoch 48/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9533
# Epoch 48: val_loss did not improve from 0.29704
# 46/46 [==============================] - 1s 28ms/step - loss: 0.1380 - accuracy: 0.9533 - val_loss: 0.4085 - val_accuracy: 0.8709
# Epoch 49/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9547
# Epoch 49: val_loss did not improve from 0.29704
# 46/46 [==============================] - 1s 28ms/step - loss: 0.1495 - accuracy: 0.9547 - val_loss: 0.3300 - val_accuracy: 0.9011
# Epoch 50/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1346 - accuracy: 0.9517
# Epoch 50: val_loss did not improve from 0.29704
# 46/46 [==============================] - 1s 28ms/step - loss: 0.1345 - accuracy: 0.9513 - val_loss: 0.3091 - val_accuracy: 0.9038
# Epoch 51/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1406 - accuracy: 0.9548
# Epoch 51: val_loss did not improve from 0.29704
# 46/46 [==============================] - 1s 28ms/step - loss: 0.1387 - accuracy: 0.9554 - val_loss: 0.4292 - val_accuracy: 0.8709
# Epoch 51: early stopping

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = len(val_acc)
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc,'r', label='Training Accuracy')
plt.plot(epochs_range, val_acc,'b', label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss,'r', label='Training Loss')
plt.plot(epochs_range, val_loss,'b', label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from keras_preprocessing import image

test_set = pd.read_csv("/content/Plant_Pathology/plant-pathology-2020-fgvc7-data/test.csv", index_col=0)

X_test = []
for index, data in test_set.iterrows():
    filepath = os.path.join(SOURCE, index + ".jpg")
    img = image.load_img(filepath, target_size=(img_height, img_width))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    X_test.append(x)
    
X_test = np.vstack(X_test)

# %%
predictions = model.predict(X_test, batch_size= 10)
score = tf.nn.softmax(predictions)
score = np.array(score)
df_out = pd.concat([test_set.reset_index(), pd.DataFrame(score, columns = class_names)], axis=1).set_index("image_id")
df_out.to_csv('submission.csv')
df_out.head()
# Out:
#            healthy  multiple_diseases      rust      scab
# image_id
# Test_0    0.174978           0.175314  0.474730  0.174978
# Test_1    0.174957           0.175222  0.474864  0.174957
# Test_2    0.176636           0.177015  0.175626  0.470722
# Test_3    0.474937           0.174948  0.174947  0.175168
# Test_4    0.174908           0.175009  0.475174  0.174908
